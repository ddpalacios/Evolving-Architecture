# %%
import numpy as np
import os 
from PIL import Image

# %%
cats = os.listdir("cats_dogs_data/PetImages/Cat/")
dogs = os.listdir("cats_dogs_data/PetImages/Dog/")

# %%
# plot dog photos from the dogs vs cats dataset
from matplotlib import pyplot
from matplotlib.image import imread
# define location of dataset
folder = '/home/daniel/github/Evolving-Architecture/dogs-vs-cats/train/'
# plot first few images
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# define filename
	filename = folder + 'dog.' + str(i) + '.jpg'
	# load image pixels
	image = imread(filename)
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %%
from matplotlib import pyplot
from matplotlib.image import imread
# define location of dataset

# plot first few images
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# define filename
	filename = folder + 'cat.' + str(i) + '.jpg'
	# load image pixels
	image = imread(filename)
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %%
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
# define location of dataset

photos, labels = list(), list()
# enumerate files in the directory
for file in listdir(folder):
    # determine classoutput = 0.0
    if file.startswith('cat'):
        output = 1.0
    # load image
    photo = load_img(folder + file, target_size=(28, 28))
    print("Resized", photo)
    # convert to numpy array
    photo = img_to_array(photo)
    # store
    photos.append(photo)
    labels.append(output)
# convert to a numpy arrays
photos = asarray(photos)
labels = asarray(labels)
print(photos.shape, labels.shape)
# save the reshaped photos
save('dogs_vs_cats_photos.npy', photos)
save('dogs_vs_cats_labels.npy', labels)
# Out:
# (25000, 28, 28, 3) (25000,)

# %%
from numpy import load
photos = load('dogs_vs_cats_photos.npy')
labels = load('dogs_vs_cats_labels.npy')
print(photos.shape, labels.shape)
# Out:
# (25000, 28, 28, 3) (25000,)

# %%
from os import listdir
src_directory = '/home/daniel/github/Evolving-Architecture/dogs-vs-cats/train'
for file in listdir(src_directory):
    print(file)
# Out:
# dog.328.jpg
# cat.2494.jpg
# dog.8707.jpg
# dog.5760.jpg
# cat.5729.jpg
# cat.4336.jpg
# cat.11726.jpg
# dog.3294.jpg
# cat.6659.jpg
# dog.6579.jpg
# cat.1836.jpg
# dog.2091.jpg
# cat.2574.jpg
# cat.1801.jpg
# dog.2829.jpg
# dog.6396.jpg
# cat.168.jpg
# cat.8724.jpg
# cat.10316.jpg
# cat.9552.jpg
# dog.11851.jpg
# dog.8765.jpg
# cat.8583.jpg
# dog.2715.jpg
# cat.9737.jpg
# dog.1454.jpg
# cat.2692.jpg
# dog.1059.jpg
# dog.5270.jpg
# dog.9692.jpg
# cat.10967.jpg
# cat.11410.jpg
# cat.2881.jpg
# dog.3506.jpg
# cat.12017.jpg
# cat.4255.jpg
# cat.10358.jpg
# dog.7253.jpg
# dog.9243.jpg
# dog.5489.jpg
# cat.9501.jpg
# cat.3466.jpg
# dog.1144.jpg
# cat.4575.jpg
# dog.4540.jpg
# cat.10013.jpg
# cat.2397.jpg
# cat.9903.jpg
# cat.10647.jpg
# cat.10124.jpg
# cat.2129.jpg
# dog.7855.jpg
# dog.9427.jpg
# dog.987.jpg
# dog.10823.jpg
# dog.11243.jpg
# cat.3234.jpg
# cat.11609.jpg
# dog.5839.jpg
# cat.3173.jpg
# dog.8868.jpg
# cat.7032.jpg
# cat.6369.jpg
# dog.5743.jpg
# dog.7074.jpg
# dog.8224.jpg
# ...

# %%
data = []
labels = []

for file in listdir('/home/daniel/github/Evolving-Architecture/dogs-vs-cats/train/'):
    if file.startswith("cat"):
        img = cv2.imread('/home/daniel/github/Evolving-Architecture/dogs-vs-cats/train/'+file)
        img = np.array(img)
        data.append(img)
        labels.append(0)


    elif file.startswith('dog'):
        img = cv2.imread('/home/daniel/github/Evolving-Architecture/dogs-vs-cats/train/'+file)
        img = np.array(img)
        data.append(img)
        labels.append(1)

save("np_data.npy", data)
save("np_labels.npy", np.array(labels))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-0bd59e77215e> in <module>()
#      11
#      12     elif file.startswith('dog'):
# ---> 13         img = cv2.imread('/home/daniel/github/Evolving-Architecture/dogs-vs-cats/train/'+file)
#      14         img = np.array(img)
#      15         data.append(img)
#
# NameError: name 'cv2' is not defined
